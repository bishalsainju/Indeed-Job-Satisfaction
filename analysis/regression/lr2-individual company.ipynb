# %%
## imports

import numpy as np
import pandas as pd

import statsmodels.formula.api as sm

# Plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline
from pprint import pprint

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import os
root = os.path.expanduser('~')

company_index='5'
company_name='Amazon'
img_path = root + '/Desktop/workspace/indeed/Job-Satisfaction/img/companies/'+f'{company_index}_{company_name}'
img_flag = False

if not os.path.exists(img_path):
    os.makedirs(img_path)
    
import warnings
warnings.filterwarnings('ignore')

# %%
def merge_data(company_list=[5]):
    df_ = pd.DataFrame()
    df_company_list = pd.read_csv( root + '/Desktop/workspace/indeed/Job-Satisfaction/data/scraper_data/indeed_site50.csv')
    for company_index in company_list:
        company_name = df_company_list.iloc[company_index - 1]['Company_Name']
        data_path = root + '/Desktop/workspace/indeed/Job-Satisfaction/data/companies/'+\
                    f'{company_index}_{company_name}/{company_name}.csv'
        df_ = pd.concat([df_, pd.read_csv(data_path)]).reset_index(drop=True)
    return df_, company_name

# %%
# ind_vars = ['Work_Life', 'Benefits', 'Job_Advancement', 'Management', 'Culture']
def create_result(ind_vars = ['Work_Life', 'Benefits', 'Job_Advancement', 'Management', 'Culture']):
    cols = ['Company_Index', 'Company_Name']
    for var in ind_vars:
        cols.extend([var+'_Coefficient', var+'_T-Value', var+'_P-Value', var+'_R-Squared'])

    df_results = pd.DataFrame(columns=cols)
    index = 0
    for i in range(1, 51):
        df, company_name = merge_data(company_list=[i])
        col_to_take = ['Rating_Number']
        col_to_take.extend(ind_vars)
    #     print(col_to_take)
        df_rating = df[col_to_take]
        df_rating.dropna(inplace=True)
        df_rating = df_rating[(df_rating[ind_vars] != 0).all(axis=1)]
        para_list = [i, company_name]
        for var in ind_vars:
            result = sm.ols(formula=f"Rating_Number ~ {var}", 
                        data=df_rating).fit()
            para_list.extend([result.params[1], result.tvalues[1], result.pvalues[1], result.rsquared])
        df_results.loc[index] = para_list
        index += 1
    return df_results

# %%
df = create_result(['Work_Life'])
df
# Out:
#    Company_Index                 Company_Name  Work_Life_Coefficient  \
# 0              1                      Walmart               0.716994
# 1              2                   Exxonmobil               0.681560
# 2              3                        Apple               0.562128
# 3              4           Berkshire-Hathaway               0.697145
# 4              5                       Amazon               0.687784
# 5              6           UnitedHealth-Group               0.747268
# 6              7                     McKesson               0.703543
# 7              8                   CVS-Health               0.756823
# 8              9                         AT&T               0.653229
# 9             10            AmerisourceBergen               0.757366
# 10            11                      Chevron               0.719733
# 11            12           Ford-Motor-Company               0.581913
# 12            13               General-Motors               0.646744
# 13            14             Costco-Wholesale               0.609344
# 14            15                       Google               0.625924
# 15            16              Cardinal-Health               0.705802
# 16            17     Walgreens-Boots-Alliance               0.664615
# 17            18               JPMorgan-Chase               0.677618
# 18            19        Verizon-Communication               0.608428
# 19            20                       Kroger               0.687992
# 20            21             General-Electric               0.643964
# 21            22                   Fannie-Mae               0.701965
# 22            23                  Phillips-66               0.677065
# 23            24                Valero-Energy               0.705272
# 24            25              Bank-of-America               0.701649
# 25            26                    Microsoft               0.570602
# 26            27                   Home-Depot               0.666451
# 27            28                       Boeing               0.640778
# 28            29                  Wells-Fargo               0.739346
# 29            30                    Citigroup               0.705691
# 30            31           Marathon-Petroleum               0.739444
# 31            32                      Comcast               0.692949
# 32            33                       Anthem               0.746081
# 33            34            Dell-Technologies               0.634468
# 34            35            DuPont-de-Nemours               0.661195
# 35            36         State-Farm-Insurance               0.706548
# 36            37            Johnson-&-Johnson               0.655231
# 37            38                          IBM               0.677534
# 38            39                       Target               0.683389
# 39            40                  Freddie-Mac               0.702360
# 40            41  United-Parcel-Service-(UPS)               0.655583
# 41            42                       Lowe's               0.686956
# 42            43                        Intel               0.598814
# 43            44                      MetLife               0.716686
# 44            45             Proctor-&-Gamble               0.633150
# 45            46          United-Technologies               0.663402
# 46            47                        FedEx               0.674767
# 47            48                      PepsiCo               0.656759
# 48            49       Archer-Daniels-Midland               0.616350
# 49            50         Prudential-Financial               0.682317
#
#     Work_Life_T-Value  Work_Life_P-Value  Work_Life_R-Squared
# 0          450.535966       0.000000e+00             0.583910
# 1           52.811026       0.000000e+00             0.562980
# 2           72.426154       0.000000e+00             0.473103
# 3           12.659399       2.089495e-23             0.586475
# 4          180.187291       0.000000e+00             0.559143
# 5          147.354104       0.000000e+00             0.619436
# 6           74.625341       0.000000e+00             0.565149
# 7          179.466195       0.000000e+00             0.635067
# 8          196.939923       0.000000e+00             0.550011
# 9           46.014535      3.346213e-274             0.621770
# 10          63.903781       0.000000e+00             0.592467
# 11          48.440367       0.000000e+00             0.471797
# 12          62.676333       0.000000e+00             0.507186
# 13          81.187509       0.000000e+00             0.509327
# 14          40.670747      5.041560e-253             0.493601
# 15          64.157137       0.000000e+00             0.593862
# 16          22.742872       1.217097e-72             0.579060
# 17         153.515205       0.000000e+00             0.560945
# 18         151.187048       0.000000e+00             0.513866
# 19         178.120364       0.000000e+00             0.552859
# 20          61.333958       0.000000e+00             0.488879
# 21          31.539469      1.152252e-150             0.507328
# 22          22.977416       1.887150e-77             0.544312
# 23          40.247363      3.332849e-219             0.593167
# 24         178.207050       0.000000e+00             0.576766
# 25          53.248571       0.000000e+00             0.451973
# 26         215.057209       0.000000e+00             0.536734
# 27          77.102190       0.000000e+00             0.508239
# 28         216.789521       0.000000e+00             0.607020
# 29         118.752637       0.000000e+00             0.573605
# 30          29.133629      5.124088e-117             0.585451
# 31         126.777266       0.000000e+00             0.561887
# 32          76.976548       0.000000e+00             0.612862
# 33          68.054410       0.000000e+00             0.490698
# 34          34.603973      2.559690e-181             0.505581
# 35         111.913434       0.000000e+00             0.584426
# 36          47.549787       0.000000e+00             0.521807
# 37          95.838250       0.000000e+00             0.511812
# 38         211.234324       0.000000e+00             0.544824
# 39          24.512231       2.988459e-93             0.492560
# 40         174.941733       0.000000e+00             0.522989
# 41         196.980006       0.000000e+00             0.566149
# 42          51.566589       0.000000e+00             0.473058
# 43          62.254690       0.000000e+00             0.590742
# 44          48.216349       0.000000e+00             0.532261
# 45          28.114169      1.080683e-120             0.502993
# 46         146.791606       0.000000e+00             0.561831
# 47          88.905624       0.000000e+00             0.550233
# 48          23.521354       1.309699e-86             0.486055
# 49          47.802250       0.000000e+00             0.517560

# %%
df = create_result(['Benefits'])
df
# Out:
#    Company_Index                 Company_Name  Benefits_Coefficient  \
# 0              1                      Walmart              0.633392
# 1              2                   Exxonmobil              0.506049
# 2              3                        Apple              0.530257
# 3              4           Berkshire-Hathaway              0.500701
# 4              5                       Amazon              0.573514
# 5              6           UnitedHealth-Group              0.693593
# 6              7                     McKesson              0.672195
# 7              8                   CVS-Health              0.640772
# 8              9                         AT&T              0.630921
# 9             10            AmerisourceBergen              0.693978
# 10            11                      Chevron              0.497266
# 11            12           Ford-Motor-Company              0.579029
# 12            13               General-Motors              0.589349
# 13            14             Costco-Wholesale              0.611892
# 14            15                       Google              0.521038
# 15            16              Cardinal-Health              0.699070
# 16            17     Walgreens-Boots-Alliance              0.663668
# 17            18               JPMorgan-Chase              0.626097
# 18            19        Verizon-Communication              0.587004
# 19            20                       Kroger              0.584278
# 20            21             General-Electric              0.599593
# 21            22                   Fannie-Mae              0.647404
# 22            23                  Phillips-66              0.439605
# 23            24                Valero-Energy              0.593241
# 24            25              Bank-of-America              0.640020
# 25            26                    Microsoft              0.514355
# 26            27                   Home-Depot              0.583631
# 27            28                       Boeing              0.620066
# 28            29                  Wells-Fargo              0.673539
# 29            30                    Citigroup              0.655177
# 30            31           Marathon-Petroleum              0.553213
# 31            32                      Comcast              0.616090
# 32            33                       Anthem              0.660307
# 33            34            Dell-Technologies              0.607441
# 34            35            DuPont-de-Nemours              0.578460
# 35            36         State-Farm-Insurance              0.546921
# 36            37            Johnson-&-Johnson              0.547680
# 37            38                          IBM              0.635624
# 38            39                       Target              0.572990
# 39            40                  Freddie-Mac              0.546130
# 40            41  United-Parcel-Service-(UPS)              0.535110
# 41            42                       Lowe's              0.617202
# 42            43                        Intel              0.601087
# 43            44                      MetLife              0.660419
# 44            45             Proctor-&-Gamble              0.593649
# 45            46          United-Technologies              0.639958
# 46            47                        FedEx              0.574929
# 47            48                      PepsiCo              0.657612
# 48            49       Archer-Daniels-Midland              0.639232
# 49            50         Prudential-Financial              0.629708
#
#     Benefits_T-Value  Benefits_P-Value  Benefits_R-Squared
# 0         361.365720      0.000000e+00            0.475332
# 1          37.871352     1.647996e-240            0.401946
# 2          56.371545      0.000000e+00            0.352780
# 3           7.685904      6.036665e-12            0.343302
# 4         113.103494      0.000000e+00            0.334098
# 5         116.311036      0.000000e+00            0.504066
# 6          59.754682      0.000000e+00            0.455517
# 7         122.317485      0.000000e+00            0.447756
# 8         137.085334      0.000000e+00            0.371873
# 9          29.851519     4.240763e-149            0.410063
# 10         42.967103     1.222142e-309            0.399589
# 11         38.470338     3.563347e-257            0.360531
# 12         44.924879      0.000000e+00            0.346227
# 13         58.226058      0.000000e+00            0.348461
# 14         31.862906     9.433317e-175            0.376122
# 15         49.847822      0.000000e+00            0.469291
# 16         17.985876      1.352328e-52            0.463129
# 17        118.038122      0.000000e+00            0.431175
# 18        102.468249      0.000000e+00            0.326985
# 19        138.391536      0.000000e+00            0.428248
# 20         47.821932      0.000000e+00            0.368627
# 21         23.918526      1.304381e-99            0.372678
# 22         13.148090      1.550668e-33            0.282069
# 23         32.615874     4.481408e-164            0.490049
# 24        130.881643      0.000000e+00            0.424073
# 25         38.637634     2.711260e-271            0.304054
# 26        175.433291      0.000000e+00            0.435890
# 27         56.618588      0.000000e+00            0.358549
# 28        160.166378      0.000000e+00            0.457814
# 29         92.266242      0.000000e+00            0.448338
# 30         19.991234      1.423982e-68            0.398991
# 31         86.910893      0.000000e+00            0.376217
# 32         51.721730      0.000000e+00            0.417525
# 33         56.456948      0.000000e+00            0.398554
# 34         24.513800     2.284921e-107            0.340097
# 35         70.732186      0.000000e+00            0.360501
# 36         35.075494     1.181512e-211            0.374371
# 37         80.936197      0.000000e+00            0.429055
# 38        163.688445      0.000000e+00            0.419442
# 39         15.762983      3.111276e-47            0.288762
# 40        123.947823      0.000000e+00            0.356046
# 41        147.278540      0.000000e+00            0.422151
# 42         40.324084     1.028653e-283            0.354717
# 43         47.614445      0.000000e+00            0.458922
# 44         40.263874     5.706322e-261            0.444380
# 45         22.755859      2.609145e-88            0.398996
# 46        111.117014      0.000000e+00            0.424660
# 47         67.159715      0.000000e+00            0.411632
# 48         18.084008      2.432836e-58            0.359758
# 49         43.283687     5.545953e-294            0.468665

# %%
df = create_result(['Job_Advancement'])
df
# Out:
#    Company_Index                 Company_Name  Job_Advancement_Coefficient  \
# 0              1                      Walmart                     0.660163
# 1              2                   Exxonmobil                     0.569919
# 2              3                        Apple                     0.539020
# 3              4           Berkshire-Hathaway                     0.544317
# 4              5                       Amazon                     0.620998
# 5              6           UnitedHealth-Group                     0.686493
# 6              7                     McKesson                     0.648983
# 7              8                   CVS-Health                     0.694920
# 8              9                         AT&T                     0.625865
# 9             10            AmerisourceBergen                     0.701695
# 10            11                      Chevron                     0.567717
# 11            12           Ford-Motor-Company                     0.573446
# 12            13               General-Motors                     0.551532
# 13            14             Costco-Wholesale                     0.552740
# 14            15                       Google                     0.467822
# 15            16              Cardinal-Health                     0.683314
# 16            17     Walgreens-Boots-Alliance                     0.710576
# 17            18               JPMorgan-Chase                     0.591726
# 18            19        Verizon-Communication                     0.582035
# 19            20                       Kroger                     0.633416
# 20            21             General-Electric                     0.569836
# 21            22                   Fannie-Mae                     0.567769
# 22            23                  Phillips-66                     0.613048
# 23            24                Valero-Energy                     0.648972
# 24            25              Bank-of-America                     0.605091
# 25            26                    Microsoft                     0.503556
# 26            27                   Home-Depot                     0.610839
# 27            28                       Boeing                     0.554142
# 28            29                  Wells-Fargo                     0.658780
# 29            30                    Citigroup                     0.617890
# 30            31           Marathon-Petroleum                     0.633649
# 31            32                      Comcast                     0.640776
# 32            33                       Anthem                     0.626728
# 33            34            Dell-Technologies                     0.571779
# 34            35            DuPont-de-Nemours                     0.549329
# 35            36         State-Farm-Insurance                     0.630721
# 36            37            Johnson-&-Johnson                     0.523230
# 37            38                          IBM                     0.612372
# 38            39                       Target                     0.609679
# 39            40                  Freddie-Mac                     0.666156
# 40            41  United-Parcel-Service-(UPS)                     0.575166
# 41            42                       Lowe's                     0.634949
# 42            43                        Intel                     0.544544
# 43            44                      MetLife                     0.631237
# 44            45             Proctor-&-Gamble                     0.570018
# 45            46          United-Technologies                     0.628248
# 46            47                        FedEx                     0.602767
# 47            48                      PepsiCo                     0.673003
# 48            49       Archer-Daniels-Midland                     0.652145
# 49            50         Prudential-Financial                     0.622702
#
#     Job_Advancement_T-Value  Job_Advancement_P-Value  \
# 0                413.386680             0.000000e+00
# 1                 44.934782            4.795464e-311
# 2                 68.640333             0.000000e+00
# 3                 10.011839             2.834026e-17
# 4                159.414395             0.000000e+00
# 5                132.904785             0.000000e+00
# 6                 67.085005             0.000000e+00
# 7                150.621951             0.000000e+00
# 8                187.102643             0.000000e+00
# 9                 38.802691            1.543660e-218
# 10                50.929938             0.000000e+00
# 11                50.499562             0.000000e+00
# 12                56.416100             0.000000e+00
# 13                71.757831             0.000000e+00
# 14                35.063872            1.859622e-202
# 15                58.457376             0.000000e+00
# 16                24.067818             4.630777e-78
# 17               136.026897             0.000000e+00
# 18               140.849221             0.000000e+00
# 19               159.557392             0.000000e+00
# 20                59.029456             0.000000e+00
# 21                28.685290            3.697936e-131
# 22                21.748234             9.536350e-72
# 23                38.962842            1.768524e-209
# 24               152.258167             0.000000e+00
# 25                50.037134             0.000000e+00
# 26               202.717403             0.000000e+00
# 27                68.903301             0.000000e+00
# 28               189.907363             0.000000e+00
# 29               107.848094             0.000000e+00
# 30                27.187880            1.394275e-106
# 31               119.309105             0.000000e+00
# 32                61.717733             0.000000e+00
# 33                64.897622             0.000000e+00
# 34                30.643692            9.995559e-152
# 35                97.887631             0.000000e+00
# 36                41.745411            2.023092e-276
# 37                98.048469             0.000000e+00
# 38               191.824065             0.000000e+00
# 39                27.189034            1.877818e-107
# 40               145.862908             0.000000e+00
# 41               185.411134             0.000000e+00
# 42                49.714570             0.000000e+00
# 43                54.022161             0.000000e+00
# 44                41.399238            2.939363e-272
# 45                28.122834            1.733586e-120
# 46               129.576846             0.000000e+00
# 47                86.831574             0.000000e+00
# 48                25.036621             2.146018e-94
# 49                47.260538             0.000000e+00
#
#     Job_Advancement_R-Squared
# 0                    0.542533
# 1                    0.485703
# 2                    0.446905
# 3                    0.470073
# 4                    0.499096
# 5                    0.570520
# 6                    0.513486
# 7                    0.551391
# 8                    0.524893
# 9                    0.539921
# 10                   0.481963
# 11                   0.493537
# 12                   0.455673
# 13                   0.448880
# 14                   0.423304
# 15                   0.548935
# 16                   0.607025
# 17                   0.501604
# 18                   0.479046
# 19                   0.499035
# 20                   0.470845
# 21                   0.461794
# 22                   0.518065
# 23                   0.579406
# 24                   0.499747
# 25                   0.423733
# 26                   0.507649
# 27                   0.453469
# 28                   0.543114
# 29                   0.526580
# 30                   0.552790
# 31                   0.532502
# 32                   0.505580
# 33                   0.467307
# 34                   0.446302
# 35                   0.519293
# 36                   0.458639
# 37                   0.524339
# 38                   0.497825
# 39                   0.546275
# 40                   0.433867
# 41                   0.536732
# 42                   0.456211
# 43                   0.521944
# 44                   0.457296
# 45                   0.505075
# 46                   0.500643
# 47                   0.539410
# 48                   0.518973
# 49                   0.513514

# %%
df = create_result(['Management'])
df
# Out:
#    Company_Index                 Company_Name  Management_Coefficient  \
# 0              1                      Walmart                0.656268
# 1              2                   Exxonmobil                0.635242
# 2              3                        Apple                0.566063
# 3              4           Berkshire-Hathaway                0.703378
# 4              5                       Amazon                0.661680
# 5              6           UnitedHealth-Group                0.705412
# 6              7                     McKesson                0.674968
# 7              8                   CVS-Health                0.703443
# 8              9                         AT&T                0.649034
# 9             10            AmerisourceBergen                0.732539
# 10            11                      Chevron                0.615283
# 11            12           Ford-Motor-Company                0.609124
# 12            13               General-Motors                0.627192
# 13            14             Costco-Wholesale                0.548623
# 14            15                       Google                0.576653
# 15            16              Cardinal-Health                0.683343
# 16            17     Walgreens-Boots-Alliance                0.708475
# 17            18               JPMorgan-Chase                0.628386
# 18            19        Verizon-Communication                0.616922
# 19            20                       Kroger                0.652045
# 20            21             General-Electric                0.633067
# 21            22                   Fannie-Mae                0.667490
# 22            23                  Phillips-66                0.653918
# 23            24                Valero-Energy                0.648369
# 24            25              Bank-of-America                0.650789
# 25            26                    Microsoft                0.542841
# 26            27                   Home-Depot                0.615553
# 27            28                       Boeing                0.596704
# 28            29                  Wells-Fargo                0.675589
# 29            30                    Citigroup                0.664632
# 30            31           Marathon-Petroleum                0.668005
# 31            32                      Comcast                0.656375
# 32            33                       Anthem                0.674507
# 33            34            Dell-Technologies                0.636314
# 34            35            DuPont-de-Nemours                0.621801
# 35            36         State-Farm-Insurance                0.655584
# 36            37            Johnson-&-Johnson                0.614079
# 37            38                          IBM                0.665421
# 38            39                       Target                0.641007
# 39            40                  Freddie-Mac                0.616315
# 40            41  United-Parcel-Service-(UPS)                0.640819
# 41            42                       Lowe's                0.646654
# 42            43                        Intel                0.614921
# 43            44                      MetLife                0.682993
# 44            45             Proctor-&-Gamble                0.635537
# 45            46          United-Technologies                0.701697
# 46            47                        FedEx                0.628168
# 47            48                      PepsiCo                0.670793
# 48            49       Archer-Daniels-Midland                0.682750
# 49            50         Prudential-Financial                0.665045
#
#     Management_T-Value  Management_P-Value  Management_R-Squared
# 0           436.978752        0.000000e+00              0.569985
# 1            53.179697        0.000000e+00              0.568563
# 2            78.589600        0.000000e+00              0.514680
# 3            15.938109        1.112823e-30              0.692118
# 4           180.813664        0.000000e+00              0.561634
# 5           152.946724        0.000000e+00              0.637513
# 6            77.903301        0.000000e+00              0.587054
# 7           170.229642        0.000000e+00              0.611042
# 8           202.261463        0.000000e+00              0.563745
# 9            47.644273       2.175499e-286              0.638176
# 10           60.061335        0.000000e+00              0.562476
# 11           59.202891        0.000000e+00              0.571870
# 12           68.438403        0.000000e+00              0.552023
# 13           83.821681        0.000000e+00              0.526019
# 14           46.949391       2.625513e-308              0.566900
# 15           65.383441        0.000000e+00              0.603132
# 16           25.790600        3.573738e-85              0.638863
# 17          156.801833        0.000000e+00              0.572161
# 18          159.440355        0.000000e+00              0.540736
# 19          182.207181        0.000000e+00              0.565093
# 20           73.275487        0.000000e+00              0.578383
# 21           40.622025       4.801146e-211              0.631238
# 22           26.256949        5.788485e-92              0.611505
# 23           39.970296       7.764150e-217              0.591138
# 24          180.610014        0.000000e+00              0.584200
# 25           59.963847        0.000000e+00              0.513251
# 26          219.273719        0.000000e+00              0.546891
# 27           85.919828        0.000000e+00              0.562788
# 28          218.891645        0.000000e+00              0.611973
# 29          127.912377        0.000000e+00              0.609697
# 30           31.691324       5.065664e-130              0.627187
# 31          131.476086        0.000000e+00              0.580437
# 32           76.188753        0.000000e+00              0.609054
# 33           79.413228        0.000000e+00              0.567615
# 34           38.334335       7.031562e-209              0.556949
# 35          110.447488        0.000000e+00              0.579270
# 36           54.579916        0.000000e+00              0.591186
# 37          112.152155        0.000000e+00              0.590574
# 38          226.914421        0.000000e+00              0.580772
# 39           26.870115       8.588321e-106              0.540016
# 40          187.314004        0.000000e+00              0.557952
# 41          206.122834        0.000000e+00              0.588672
# 42           62.067534        0.000000e+00              0.565497
# 43           66.776742        0.000000e+00              0.625568
# 44           53.450877        0.000000e+00              0.583895
# 45           37.260073       1.357126e-175              0.639389
# 46          144.174933        0.000000e+00              0.553737
# 47           95.703706        0.000000e+00              0.587008
# 48           32.754830       2.872827e-134              0.647921
# 49           55.482923        0.000000e+00              0.591723

# %%
# df = create_result(['Culture'])
# df

# %%
# ind_vars = ['Work_Life', 'Benefits', 'Job_Advancement', 'Management', 'Culture']
def create_result(ind_vars = ['Work_Life', 'Benefits', 'Job_Advancement', 'Management', 'Culture']):
    cols = ['Company_Index', 'Company_Name']
    for var in ind_vars:
        cols.extend([var+'_Coefficient', var+'_T-Value', var+'_P-Value'])
    cols.append('R-Squared')

    df_results = pd.DataFrame(columns=cols)
    index = 0
    for i in range(1, 51):
        df, company_name = merge_data(company_list=[i])
        col_to_take = ['Rating_Number']
        col_to_take.extend(ind_vars)
    #     print(col_to_take)
        df_rating = df[col_to_take]
        df_rating.dropna(inplace=True)
        para_list = [i, company_name]
        result = sm.ols(formula="Rating_Number ~ Work_Life", 
                data=df_rating).fit()
        for j in range(1, 6):
            para_list.extend([result.params[j], result.tvalues[j], result.pvalues[j]])
        para_list.append(result.rsquared)
        df_results.loc[index] = para_list
        index += 1
    return df_results

# %%
df = create_result(["Work_Life"])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-d8a559b4d0fe> in <module>
# ----> 1 df = create_result(["Work_Life"])
#       2 df
#
# <ipython-input-32-dc725b5264c0> in create_result(ind_vars)
#      19                 data=df_rating).fit()
#      20         for j in range(1, 6):
# ---> 21             para_list.extend([result.params[j], result.tvalues[j], result.pvalues[j]])
#      22         para_list.append(result.rsquared)
#      23         df_results.loc[index] = para_list
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4409
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#    4413                 raise
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds
